# %%
import pandas as pd
import numpy as np

import pickle

# %%
with open('result/embeddings_v1.pkl', 'rb') as file:
    embeddings = pickle.load(file)

# %%
from pathlib import Path
full_dataset = pd.concat([pd.read_csv(str(x.resolve())) for x in Path("data/").glob("*k.csv")])

columns = ['Id', 'Name', 'RatingDist1', 'RatingDist2', 'RatingDist3',
           'RatingDist4', 'RatingDist5', 'Rating', 'RatingDistTotal', 'pagesNumber', 'Publisher',
           'Authors', 'Language', 'Description']
full_dataset = full_dataset[columns]

full_dataset = full_dataset[~full_dataset['Description'].isna()]
full_dataset['RatingDistTotal'] = full_dataset['RatingDistTotal'].apply(lambda x: float(x.replace('total:', '')))

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

full_dataset = reduce_mem_usage(full_dataset)

# %%
import re

def text_preprocessing_step(text):
    text = text.lower()

    # Удаляем html-теги
    re_html = re.compile(r'<.*?>')
    text = re_html.sub(' ', text)

    return text.strip()

full_dataset = full_dataset[full_dataset['Description'].apply(len) >= 50]
full_dataset = full_dataset[full_dataset['RatingDistTotal'] >= 2000]

descriptions = full_dataset['Description'].apply(text_preprocessing_step)

# %%
full_dataset[['Name', 'Authors']].reset_index(drop=True)[:30]
# Out:
#                                                  Name            Authors
# 0                       Haroun and the Sea of Stories     Salman Rushdie
# 1               There and Back Again: An Actor's Tale         Sean Astin
# 2                                            Feu Pâle   Vladimir Nabokov
# 3                                Anne of Green Gables    L.M. Montgomery
# 4                     Trojan Odyssey (Dirk Pitt, #17)      Clive Cussler
# 5         Jackie & Me (A Baseball Card Adventure, #2)         Dan Gutman
# 6                   Shenzhen: A Travelogue from China        Guy Delisle
# 7          Honus & Me (A Baseball Card Adventure, #1)         Dan Gutman
# 8   Lighthouse at the End of the World: The First ...        Jules Verne
# 9                  Lighthouse at the End of the World        Jules Verne
# 10                                          Cold Fire        Dean Koontz
# 11                                           Whispers        Dean Koontz
# 12                               The Door to December        Dean Koontz
# 13  My Secret War: The World War II Diary of Madel...  Mary Pope Osborne
# 14  City of Quartz: Excavating the Future of Los A...        Mike  Davis
# 15  The Power of One (Young Readers Condensed Edit...    Bryce Courtenay
# 16  Healthy Sleep Habits, Happy Child: A step-by-s...    Marc Weissbluth
# 17                  Healthy Sleep Habits, Happy Child    Marc Weissbluth
# 18                   Accidental Death of an Anarchist           Dario Fo
# 19                      The Architecture of Happiness    Alain de Botton
# 20              Naruto, Vol. 16: Eulogy (Naruto, #16)  Masashi Kishimoto
# 21               Killing Orders (V.I. Warshawski, #3)      Sara Paretsky
# 22              Bitter Medicine (V.I. Warshawski, #4)      Sara Paretsky
# 23                                   Windy City Blues      Sara Paretsky
# 24   To Live is Christ: Embracing the Passion of Paul         Beth Moore
# 25                         The Night Before Christmas   Clement C. Moore
# 26                                           Caucasia        Danzy Senna
# 27                    Sunset Express (Elvis Cole, #6)       Robert Crais
# 28                               The Canterbury Tales   Geoffrey Chaucer
# 29                          Pollyanna (Pollyanna, #1)  Eleanor H. Porter

# %%
embeddings.shape[0]
# Out:
# 66520

# %%
pair_distances = np.zeros((embeddings.shape[0], 10))

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
# %%time

# idx = 66515
idx = 16

# distances = np.linalg.norm(embeddings - embeddings[idx], axis=1)
# distances = cosine_distances(embeddings, embeddings[idx].reshape(1, -1))
# distances = distances.reshape(1, -1)[0]

# Получается нормальный результат только со скалярным произведением
distances = np.dot(embeddings, embeddings[idx])
# Out:
# Wall time: 12.1 ms

# %%
indexes = np.argsort(distances)[::-1][:50]

# %%
indexes
# Out:
# array([  958, 55309,  9236, 18970,  6267, 58902, 16963, 41825, 62336,
#        39348, 33432, 40396, 40328, 12791, 48138,  9338, 15723, 35759,
#        43358, 34489, 31978, 64650, 13686, 29836, 41100, 15795, 21377,
#        35802, 41543, 62867, 34067, 62837, 56814, 56813, 34453, 60261,
#         2457,  2458, 44161, 34365, 15486, 17045, 44131, 32449, 60199,
#         8879, 14667, 44267,  3189, 50051], dtype=int64)

# %%
tmp = full_dataset.iloc[indexes]
tmp[tmp['Language'] == 'eng']
# Out:
#              Id                                               Name  \
# 9342     921651           Just Go To Bed (A Golden Look-Look Book)
# 310236  2764081                 There's A Nightmare In My Cupboard
# 29774   1074339                                  The Napping House
# 74375   2167752                   Beggars in Spain (Sleepless, #1)
# 282734  2688334  The Happiest Toddler on the Block: How to Elim...
# 208475  3588707  Junie B. Jones Has a Monster Under Her Bed (Ju...
# 254738  3719743                      What to Expect the First Year
# 21422   1949561  Have You Filled a Bucket Today?: A Guide to Da...
# 18133    833046                    I Am Not Going to Get up Today!
# 364436  2911868                                              Parts
#
#        RatingDist1 RatingDist2 RatingDist3 RatingDist4 RatingDist5  Rating  \
# 9342         1:395       2:914      3:4717      4:6926     5:13939    4.23
# 310236       1:143       2:429      3:2633      4:4454      5:7453    4.23
# 29774        1:690      2:1527      3:6282     4:11335     5:23099    4.27
# 74375        1:144       2:390      3:1529      4:2899      5:2298    3.94
# 282734       1:183       2:778      3:2049      4:2054      5:1203    3.53
# 208475       1:236       2:537      3:1809      4:2001      5:3555    4.00
# 254738       1:411       2:897      3:3838      4:5626      5:5131    3.89
# 21422         1:80       2:137       3:537      4:1128      5:2988    4.40
# 18133         1:48       2:242      3:1120      4:1177      5:1753    4.00
# 364436       1:194       2:469      3:1903      4:3138      5:6716    4.27
#
#         RatingDistTotal  pagesNumber                             Publisher  \
# 9342            26891.0         24.0  Random House Books for Young Readers
# 310236          15112.0          NaN                          Puffin Books
# 29774           42933.0         32.0             Harcourt Children's Books
# 74375            7260.0          NaN                        William Morrow
# 282734           6267.0          NaN                                Bantam
# 208475           8138.0          NaN                      Turtleback Books
# 254738          15903.0          NaN            Workman Publishing Company
# 21422            4870.0          NaN                           Ferne Press
# 18133            4340.0         48.0  Random House Books for Young Readers
# 364436          12420.0          NaN                            Dial Books
#
#               Authors Language  \
# 9342     Mercer Mayer      eng
# 310236   Mercer Mayer      eng
# 29774     Audrey Wood      eng
# 74375     Nancy Kress      eng
# 282734    Harvey Karp      eng
# 208475   Barbara Park      eng
# 254738  Heidi Murkoff      eng
# 21422   Carol McCloud      eng
# 18133       Dr. Seuss      eng
# 364436    Tedd Arnold      eng
#
#                                               Description
# 9342    Mercer Mayer's Little Critter is not looking f...
# 310236  The pesky nightmare in the closet won't stay i...
# 29774   A cozy bed, a snoring granny, a dreaming child...
# 74375   In the year 2008, thanks to a stunning scienti...
# 282734  <b>Perfect for expecting parents who want to p...
# 208475  After hearing from a classmate at kindergarten...
# 254738  Some things about babies, happily, will never ...
# 21422   Through sweet, simple prose and vivid illustra...
# 18133   "A rhyming story that is full of laughs. 'The ...
# 364436  I just don't know what's going onOr why it has...
